# %% [markdown]
# ## Importing relevant packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Dataset

# %%
train=pd.read_csv('train.csv')
print(train.shape)
# Out:
# (1628, 29)

# %%
test=pd.read_csv('test.csv')
print(test.shape)
# Out:
# (470, 28)

# %%
target=train.Attrition
print(target.shape)
# Out:
# (1628,)

# %%
data=pd.concat([train,test],ignore_index=True)

# %%
data.head()
# Out:
#    Id  Age  Attrition BusinessTravel              Department  \
# 0   1   30        0.0     Non-Travel  Research & Development
# 1   2   36        0.0  Travel_Rarely  Research & Development
# 2   3   55        1.0  Travel_Rarely                   Sales
# 3   4   39        0.0  Travel_Rarely  Research & Development
# 4   5   37        0.0  Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeNumber  \
# 0                 2          3        Medical             571
# 1                12          4  Life Sciences            1614
# 2                 2          1        Medical             842
# 3                24          1  Life Sciences            2014
# 4                 3          3          Other             689
#
#    EnvironmentSatisfaction  ... PerformanceRating  StockOptionLevel  \
# 0                        3  ...                 3                 0
# 1                        3  ...                 3                 2
# ...

# %%
data.isnull().sum()
# Out:
# Id                           0
# Age                          0
# Attrition                  470
# BusinessTravel               0
# Department                   0
# DistanceFromHome             0
# Education                    0
# EducationField               0
# EmployeeNumber               0
# EnvironmentSatisfaction      0
# Gender                       0
# JobInvolvement               0
# JobRole                      0
# JobSatisfaction              0
# MaritalStatus                0
# MonthlyIncome                0
# NumCompaniesWorked           0
# OverTime                     0
# PercentSalaryHike            0
# PerformanceRating            0
# StockOptionLevel             0
# TotalWorkingYears            0
# TrainingTimesLastYear        0
# YearsAtCompany               0
# YearsInCurrentRole           0
# YearsSinceLastPromotion      0
# YearsWithCurrManager         0
# CommunicationSkill           0
# Behaviour                    0
# dtype: int64

# %%
target
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 1623    1
# 1624    1
# 1625    1
# 1626    1
# 1627    1
# Name: Attrition, Length: 1628, dtype: int64

# %% [markdown]
# ## EDA

# %%
cols=['Age','DistanceFromHome','MonthlyIncome','NumCompaniesWorked','PercentSalaryHike','TotalWorkingYears','TrainingTimesLastYear','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager','EmployeeNumber']
data[cols].corr()
# Out:
#                               Age  DistanceFromHome  MonthlyIncome  \
# Age                      1.000000          0.003522       0.508303
# DistanceFromHome         0.003522          1.000000      -0.006312
# MonthlyIncome            0.508303         -0.006312       1.000000
# NumCompaniesWorked       0.306305         -0.046058       0.159359
# PercentSalaryHike        0.014521          0.076175      -0.046386
# TotalWorkingYears        0.678917          0.010001       0.769240
# TrainingTimesLastYear    0.001333         -0.037525      -0.013633
# YearsAtCompany           0.347370         -0.013102       0.534256
# YearsInCurrentRole       0.257940         -0.001894       0.404933
# YearsSinceLastPromotion  0.224033          0.009479       0.347016
# YearsWithCurrManager     0.254195         -0.001955       0.385938
# EmployeeNumber           0.016430          0.039946       0.008412
#
#                          NumCompaniesWorked  PercentSalaryHike  \
# ...

# %%
sns.heatmap(data[cols].corr(),)

# %% [raw]
# we do not see a high correlation between any two variables except those which are associated with experience/years spent in the company or under a manager

# %%
p=sns.FacetGrid(data,col='Gender',row='OverTime')
p.map(sns.countplot,'Attrition')
#sns.countplot('Gender',data=data,hue='Attrition')

# %%
p=sns.FacetGrid(data,col='Gender',row='PerformanceRating')
p.map(sns.countplot,'Attrition')

# %%
p=sns.FacetGrid(data,col='MaritalStatus',row='PerformanceRating')
p.map(sns.countplot,'Attrition')

# %% [raw]
# # Histograms

# %%
sns.distplot(data['MonthlyIncome'],bins=20)

# %%
sns.distplot(data['EmployeeNumber'],bins=20)

# %% [raw]
# # Boxplots

# %%
sns.boxplot(x='Education',y='MonthlyIncome',data=data)

# %%
sns.boxplot(x='PerformanceRating',y='MonthlyIncome',data=data)

# %%
plt.figure(figsize=(200,1))

# %%
sns.boxplot(x='JobRole',y='MonthlyIncome',data=data)

# %%
sns.pairplot(data,corner=True)

# %%
data.drop(['Attrition'],axis=1,inplace=True)

# %% [markdown]
# ## Encoding Ordinal variables

# %%
from sklearn.preprocessing import OrdinalEncoder
cols=["Education","EnvironmentSatisfaction","JobInvolvement","JobSatisfaction","OverTime","PerformanceRating","StockOptionLevel","CommunicationSkill"]
oe=OrdinalEncoder()
data[cols]=oe.fit_transform(data[cols])

# %% [markdown]
# ## Encoding Categorical variables

# %%
from sklearn.preprocessing import LabelEncoder
cols=['BusinessTravel','Department','EducationField','Gender','JobRole','MaritalStatus']
le=LabelEncoder()
for col in cols:
    data[col]=le.fit_transform(data[col])

# %%
data
# Out:
#        Id  Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0       1   30               0           1                 2        2.0
# 1       2   36               2           1                12        3.0
# 2       3   55               2           2                 2        0.0
# 3       4   39               2           1                24        0.0
# 4       5   37               2           1                 3        2.0
# ...   ...  ...             ...         ...               ...        ...
# 2093  466   32               2           1                 2        3.0
# 2094  467   18               1           2                 3        1.0
# 2095  468   24               2           1                23        2.0
# 2096  469   31               2           1                23        2.0
# 2097  470   36               2           1                 5        3.0
#
#       EducationField  EmployeeNumber  EnvironmentSatisfaction  Gender  ...  \
# ...

# %% [markdown]
# ## Transforming continous variables

# %%
data["MonthlyIncome"]=data["MonthlyIncome"]/1000
data["EmployeeNumber"]=data["EmployeeNumber"]/1000

# %%
cols=['Age','DistanceFromHome','MonthlyIncome','NumCompaniesWorked','PercentSalaryHike','TotalWorkingYears','TrainingTimesLastYear','YearsAtCompany','YearsInCurrentRole','YearsSinceLastPromotion','YearsWithCurrManager','EmployeeNumber']

# %%
for col in cols:
    data[col]=data[col]-data[col].mean()/data[col].std()

# %%
data[cols].describe()
# Out:
#        BusinessTravel   Department  EducationField       Gender      JobRole  \
# count     2098.000000  2098.000000     2098.000000  2098.000000  2098.000000
# mean        -0.900377    -1.064123        0.597207    -0.635888     2.784871
# std          0.640055     0.547845        1.354834     0.488480     2.509208
# min         -2.501425    -2.353446       -1.683060    -1.243133    -1.845253
# 25%         -1.501425    -1.353446       -0.683060    -1.243133     0.154747
# 50%         -0.501425    -1.353446        0.316940    -0.243133     4.154747
# 75%         -0.501425    -0.353446        1.316940    -0.243133     5.154747
# max         -0.501425    -0.353446        3.316940    -0.243133     6.154747
#
#        MaritalStatus
# count    2098.000000
# mean       -0.409237
# std         0.741047
# min        -1.580352
# 25%        -0.580352
# 50%        -0.580352
# 75%         0.419648
# max         0.419648

# %%
data_train=data.iloc[0:1628,1:]
data_test=data.iloc[1628:,1:]

# %%
data_train
# Out:
#       Age  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      30       -2.501425   -1.353446                 2        2.0
# 1      36       -0.501425   -1.353446                12        3.0
# 2      55       -0.501425   -0.353446                 2        0.0
# 3      39       -0.501425   -1.353446                24        0.0
# 4      37       -0.501425   -1.353446                 3        2.0
# ...   ...             ...         ...               ...        ...
# 1623   42       -1.501425   -1.353446                19        2.0
# 1624   55       -0.501425   -0.353446                 2        0.0
# 1625   25       -0.501425   -0.353446                 9        1.0
# 1626   29       -0.501425   -2.353446                13        2.0
# 1627   29       -0.501425   -1.353446                18        0.0
#
#       EducationField  EmployeeNumber  EnvironmentSatisfaction    Gender  \
# 0            1.31694        0.000571                      2.0 -1.243133
# ...

# %% [markdown]
# ## Hyper-parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

#clf=GridSearchCV(svm.SVC(gamma='auto'),{
clf=GridSearchCV(LogisticRegression(),{
    'C':[7,8,9,10,12],
    #'degree':[2,3,4,5]
    #'kernel':['rbf','linear']
    }, cv=5,  return_train_score=False)
clf.fit(data_train,target)
# Out:
# C:\Users\Utkarsh\anac\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\Utkarsh\anac\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
clf.best_params_
# Out:
# {'C': 7}

# %%
model_params = {
    'svm':{
        'model': svm.SVC(gamma='auto',kernel='sigmoid'),
        'params':{
            'C':[5,10,15,20],
            'degree':[2,3,4,5]
            #'C':[3,4,5,6,7]
            #'kernel':['rbf','linear','poly', 'sigmoid']
        }
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params':{
            'n_estimators':[50,100,200],
            'max_depth':[5,10,15],
            'min_samples_leaf':[5,6,7,8,],
            'criterion':['gini','entropy'],
            'max_features':['sqrt','log2']
        }
    },
    'logistic_regression':{
        'model': LogisticRegression(solver='saga',multi_class='auto'),
        'params':{
            'C':[3,4,5,6,7,8],
            'solver' : ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga']
        }
        
    }
}

# %%
scores=[]

for model_name, mp in model_params.items():
    clf= GridSearchCV(mp['model'],mp['params'], cv=5,return_train_score=False)
    clf.fit(data_train,target)
    scores.append({
        'model': model_name,
        'best_score':clf.best_score_,
        'best_params':clf.best_params_
    })
# Out:
# C:\Users\Utkarsh\anac\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\Utkarsh\anac\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
scores
# Out:
# [{'model': 'svm',
#   'best_score': 0.5178121755545069,
#   'best_params': {'C': 5, 'degree': 2}},
#  {'model': 'random_forest',
#   'best_score': 0.958852288815479,
#   'best_params': {'criterion': 'entropy',
#    'max_depth': 15,
#    'max_features': 'log2',
#    'min_samples_leaf': 5,
#    'n_estimators': 100}},
#  {'model': 'logistic_regression',
#   'best_score': 0.7641340254837188,
#   'best_params': {'C': 7, 'solver': 'lbfgs'}}]

# %% [markdown]
# ## Using RandomForestClassifier model

# %%
RFC=RandomForestClassifier(n_estimators=100,max_depth=15,max_features='log2',min_samples_leaf=5,criterion='entropy')

# %%
from sklearn.metrics import make_scorer
def ras(y,y_pred):
    return roc_auc_score(y,y_pred)
RAS=make_scorer(ras, greater_is_better=True)

# %%
from sklearn.metrics import roc_auc_score
from sklearn.model_selection import cross_val_score
scores = cross_val_score(RFC, data_train, target, cv=5,scoring=RAS)
scores
# Out:
# array([0.9556213 , 0.9556213 , 0.94970414, 0.9672619 , 0.96130952])

# %%
RFC.fit(data_train,target)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='entropy', max_depth=15, max_features='log2',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=5, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
submission_rfc=RFC.predict_proba(data_test)

# %%
submission_rfc[:,1]
# Out:
# array([0.14759116, 0.18265229, 0.17961169, 0.26095899, 0.0928189 ,
#        0.11587027, 0.68127432, 0.22434397, 0.26206566, 0.13407942,
#        0.14400219, 0.37184146, 0.20334979, 0.05918728, 0.11762594,
#        0.11091094, 0.53629947, 0.28351543, 0.24895775, 0.0325754 ,
#        0.12397292, 0.61183598, 0.26292669, 0.14407564, 0.18796111,
#        0.0760108 , 0.09621784, 0.11594829, 0.84563951, 0.09582213,
#        0.13997394, 0.17068591, 0.41528384, 0.34641324, 0.10001687,
#        0.12610638, 0.18064189, 0.16143795, 0.35810647, 0.33348651,
#        0.74748069, 0.28684938, 0.12739766, 0.17462997, 0.10953392,
#        0.11498264, 0.26874551, 0.25938358, 0.07546591, 0.25570999,
#        0.56801595, 0.12186166, 0.34228988, 0.64817371, 0.32911975,
#        0.27409544, 0.09337959, 0.68819392, 0.03734363, 0.19498224,
#        0.16326876, 0.12176016, 0.54951611, 0.03636652, 0.16048011,
#        0.20450561, 0.16263008, 0.14861452, 0.25707846, 0.15835208,
# ...

# %%
np.savetxt('Submission_RFC.csv',submission_rfc[:,1])

# %%
print("The End")
# Out:
# The End
